# %%
import pandas as pd

df_complet = pd.read_csv("dataREanonymized_long.csv")

# la liste exacte des patients 
patients_a_garder = ['uznrjkmtisetxsg', 'uthjemmvtwogzcc', 'mcnjbkdjdsycrjf', 'xvyeentnlfrcyyx', 'azexpgpszpmglxf', 'dfngrvjkictscmy']

# on filtre le tableau pour ne garder QUE ces patients
df_petit = df_complet[df_complet['subject_id'].isin(patients_a_garder)]

df_petit.to_csv("../../API/DataTest_long.csv", index=False)

print(f"Extraction réussie ! Le nouveau fichier contient {len(df_petit)} lignes.")
# Out:
# ✅ Extraction réussie ! Le nouveau fichier contient 396 lignes.
# C:\Users\2432741\AppData\Local\Temp\ipykernel_9508\1399370355.py:3: DtypeWarning: Columns (0: Value) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_complet = pd.read_csv("dataREanonymized_long.csv")
